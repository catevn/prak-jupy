# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

U = np.arange(0, 850, 50)
N_dunkel = np.array([0, 0, 0, 0, 0, 0, 0, 0, 1, 2, 18, 50, 134, 66, 222, 385, 563])
N_hell = np.array([0, 0, 0, 0, 0, 0, 0, 0, 3, 2302, 10264, 14360, 15313, 16194, 16744, 17113, 17942])
t_mess = 20 #s
du = 10 #V

plt.errorbar(U, N_dunkel / t_mess, yerr=np.sqrt(N_dunkel)/t_mess, xerr=du, label='Dunkelmessung', fmt='.')
plt.errorbar(U, N_hell / t_mess, yerr=np.sqrt(N_hell)/t_mess, xerr=du, label='Hellmessung', fmt='.')
plt.xlabel('PM-Spannung [V]')
plt.ylabel('Zählrate [1/s]')
np.sqrt(N_hell)/t_mess
plt.legend()
plt.savefig('images/kennlinie.png', dpi=300)
